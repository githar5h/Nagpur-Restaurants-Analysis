# %%
# import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('dataset_cleaned.csv')
df.head()
# Out:
#               Restaurant Name Most Popular Category  Rating  Cost for two  \
# 0             Biryani By Kilo               Biryani     4.1           600
# 1  Haldirams Sweets & Namkeen         Multi-cuisine     4.6           300
# 2                Pind Punjabi          North Indian     3.3           200
# 3             Behrouz Biryani               Biryani     3.9           500
# 4        Jay Ambika Bhojnalay          North Indian     4.0           300
#
#                 Area                       Locality  \
# 0         Khare Town                     Dharampeth
# 1          Sitabuldi                      SITABULDI
# 2           Loha Pul                 Loha Pul, Pind
# 3              Sadar  Azad Chowk, Near Gandhi Chowk
# 4  Ganeshpeth Colony                     Gandhibagh
#
#                                              Address    Veg  \
# 0  Commercial First Floor, F1 & F2 INDU YASH II, ...  False
# 1                   ABHYANKAR ROAD, SITABULDI,NAGPUR  False
# ...

# %% [markdown]
# ## Analysis 3: Rating and Cost Analysis

# %% [markdown]
# ##### The relationship between restaurant ratings and the cost for two is examined, and the distribution of costs based on rating ranges is analyzed.

# %%
# Create rating ranges
df['Rating Range'] = pd.cut(df['Rating'], bins=[0, 3, 4, 5], labels=['Low', 'Medium', 'High'])

# %%
# Line plot of average cost for two across different rating ranges
plt.figure(figsize=(10, 6))
sns.lineplot(x='Rating Range', y='Cost for two', data=df, errorbar=None)
plt.title('Average Cost for Two Across Ratings')
plt.show()

# %%
# Violin plot of cost by rating range
plt.figure(figsize=(12, 6))
sns.violinplot(x='Rating Range', y='Cost for two', data=df)
plt.title('Distribution of Costs Based on Rating Ranges')
plt.show()
